# %% [markdown]
# <a href="https://colab.research.google.com/github/CHINNARAT241144/Data-Engineer/blob/main/Lab_05_6606022420010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Workshop 5: Data Quality**
# **คำสั่ง**
#
# 1.   ศึกษาวิธีการตรวจสอบคุณภาพของข้อมูลชุดข้อมูล transaction data
# 2.   ทำการตรวจสอบคุณภาพของข้อมูล ชุดข้อมูล customer data  โดยทำปฏิบัติการแต่ละข้อ
# 3.   ตั้งชื่อไฟล์ python notebook นี้ในรูปแบบ Lab_05_XXXXXXXXXXXXX.ipynb โดย XXXXXXXXX คือ รหัสนักศึกษา
# 4.   ทำการดาวน์โหลดและส่งไฟล์ Lab_05_XXXXXXXXXXXXX.ipynb ที่ Google Classroom

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
transaction_data = pd.read_csv("/content/drive/MyDrive/DATA-ENGINEER/lab_5/transaction_data.csv", na_values=-999)
transaction_data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    txn_id cust_id  price process_date
# 0       1       v   89.0     1/5/2021
# 1       2       y   60.0     1/5/2021
# 2       3       m   55.0     1/5/2021
# 3       4       s    NaN     1/5/2021
# 4       5       z   50.0     1/5/2021
# 5       6       s   41.0     2/5/2021
# 6       7       s    NaN    15/5/2021
# 7       8       e   23.0     1/5/2021
# 8       9       n   12.0     1/5/2021
# 9      10       x   87.0     1/5/2021

# %% [markdown]
# # Missing values

# %%
# detect missing values
missingValues = transaction_data.isna()
print(missingValues)
# Out:
#    txn_id  cust_id  price  process_date
# 0   False    False  False         False
# 1   False    False  False         False
# 2   False    False  False         False
# 3   False    False   True         False
# 4   False    False  False         False
# 5   False    False  False         False
# 6   False    False   True         False
# 7   False    False  False         False
# 8   False    False  False         False
# 9   False    False  False         False

# %%
# count the number of missing data
num_missing = missingValues.values.sum()
print(num_missing)
# Out:
# 2

# %%
# count the number of rows having missing data
row_missing = missingValues.sum(axis=1)
print(row_missing)
num_row_missing = np.count_nonzero(row_missing)
print("There are %d rows contain missing values"%(num_row_missing))
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# 5    0
# 6    1
# 7    0
# 8    0
# 9    0
# dtype: int64
# There are 2 rows contain missing values

# %%
# count the number of columns having missing data
col_missing = missingValues.sum()
print(col_missing)
num_col_missing = np.count_nonzero(col_missing)
print("There are %d columns contain missing values"%(num_col_missing))
# Out:
# txn_id          0
# cust_id         0
# price           2
# process_date    0
# dtype: int64
# There are 1 columns contain missing values

# %% [markdown]
# # Duplicated records

# %%
transaction_data[transaction_data.duplicated(['cust_id'])]
# Out:
#    txn_id cust_id  price process_date
# 5       6       s   41.0     2/5/2021
# 6       7       s    NaN    15/5/2021

# %%
transaction_data[transaction_data.duplicated(['txn_id'])]
# Out:
# Empty DataFrame
# Columns: [txn_id, cust_id, price, process_date]
# Index: []

# %%
transaction_data[transaction_data.duplicated(['txn_id','cust_id'])]
# Out:
# Empty DataFrame
# Columns: [txn_id, cust_id, price, process_date]
# Index: []

# %% [markdown]
# ปฏิบัติการข้อ 1) จงอ่านชุดข้อมูล Customer Data จากไฟล์ customer_data.csv โดยเก็บไว้ในตัวแปล customer_data (ข้อมูลสูญหาย ถูกแทนด้วยช่องว่าง)

# %%
from google.colab import drive
drive.mount('/content/drive')
customer_data = pd.read_csv("/content/drive/MyDrive/DATA-ENGINEER/lab_5/customer_data.csv", na_values=-999)
customer_data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   cust_id   age wealth_segment process_date
# 0       e  44.0            NaN   2020-01-05
# 1       m  30.0         medium   2020-01-05
# 2       n  29.0           poor   2020-01-05
# 3       s  64.0           rich   2020-01-05
# 4       v   NaN         medium   2020-01-05
# 5       x  40.0           poor   2020-01-05
# 6       y  41.0           rich   2020-01-05
# 7       z  43.0           rich   2020-01-05
# 8       s -12.0           rich   2020-01-05
# 9       z  54.0           rich   2021-01-05

# %% [markdown]
# ปฏิบัติการข้อ 2) จงนับจำนวนข้อมูลสูญหายทั้งหมดในชุดข้อมูล Customer Data

# %%
missingValues = customer_data.isna()
num_missing = missingValues.values.sum()
# print(missingValues)
print(num_missing)
# Out:
# 2

# %% [markdown]
# ปฏิบัติการข้อ 3) จงนับจำนวนคอลัมน์ในชุดข้อมูล Customer Data ที่มีข้อมูลสูญหาย

# %%
col_missing = missingValues.sum()
print(col_missing)
num_col_missing = np.count_nonzero(col_missing)
print("There are %d columns contain missing values"%(num_col_missing))
# Out:
# cust_id           0
# age               1
# wealth_segment    1
# process_date      0
# dtype: int64
# There are 2 columns contain missing values

# %% [markdown]
# ปฏิบัติการข้อ 4) จงนับจำนวนแถวข้อมูลในชุดข้อมูล Customer Data ที่มีข้อมูลสูญหาย

# %%
row_missing = missingValues.sum(axis=1)
print(row_missing)
num_row_missing = np.count_nonzero(row_missing)
print("There are %d rows contain missing values"%(num_row_missing))
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# 5    0
# 6    0
# 7    0
# 8    0
# 9    0
# dtype: int64
# There are 2 rows contain missing values

# %% [markdown]
# ปฏิบัติการข้อ 5) จงหาลูกค้าที่มีการบันทึกข้อมูลในชุดข้อมูล Customer Data ในหลายระเบียนข้อมูล

# %%
customer_data[customer_data.duplicated(['cust_id'])]
# Out:
#   cust_id   age wealth_segment process_date
# 8       s -12.0           rich   2020-01-05
# 9       z  54.0           rich   2021-01-05

# %% [markdown]
# ปฏิบัติการข้อ 6) จงหาลูกค้าที่มีค่าข้อมูลอายุ (age) ไม่อยู่ในขอบเขตข้อมูลที่ถูกต้อง

# %%
invalid_age_data = customer_data[customer_data['age'].isna()]
print(invalid_age_data)
# Out:
#   cust_id  age wealth_segment process_date
# 4       v  NaN         medium   2020-01-05

# %% [markdown]
# ปฏิบัติการข้อ 7) จงหาลูกค้าที่มีค่าข้อมูลอายุ (age) ผิดปรกติ ไม่สอดคล้องความเป็นจริง

# %%
valid_age_min = 0
invalid_age_data = customer_data[customer_data['age'] < valid_age_min ]
print(invalid_age_data)
# Out:
#   cust_id   age wealth_segment process_date
# 8       s -12.0           rich   2020-01-05

# %% [markdown]
# # Expand customer information in transaction data using information in customer data

# %%
# Expand customer information in transaction data
txn_with_cust = transaction_data.merge(customer_data, on='cust_id', how='left')
txn_with_cust
# Out:
#    cust_id  age_x wealth_segment_x process_date_x  age_y wealth_segment_y  \
# 0        e   44.0              NaN     2020-01-05   44.0              NaN
# 1        m   30.0           medium     2020-01-05   30.0           medium
# 2        n   29.0             poor     2020-01-05   29.0             poor
# 3        s   64.0             rich     2020-01-05   64.0             rich
# 4        s   64.0             rich     2020-01-05  -12.0             rich
# 5        v    NaN           medium     2020-01-05    NaN           medium
# 6        x   40.0             poor     2020-01-05   40.0             poor
# 7        y   41.0             rich     2020-01-05   41.0             rich
# 8        z   43.0             rich     2020-01-05   43.0             rich
# 9        z   43.0             rich     2020-01-05   54.0             rich
# 10       s  -12.0             rich     2020-01-05   64.0             rich
# 11       s  -12.0             rich     2020-01-05  -12.0             rich
# 12       z   54.0             rich     2021-01-05   43.0             rich
# 13       z   54.0             rich     2021-01-05   54.0             rich
#
#    process_date_y
# 0      2020-01-05
# 1      2020-01-05
# 2      2020-01-05
# 3      2020-01-05
# 4      2020-01-05
# 5      2020-01-05
# 6      2020-01-05
# 7      2020-01-05
# 8      2020-01-05
# 9      2021-01-05
# 10     2020-01-05
# 11     2020-01-05
# 12     2020-01-05
# 13     2021-01-05

# %% [markdown]
# ปฏิบัติการข้อ 8) จากการรวมตารางข้อมูล transaction_data และ customer_data ข้างต้นจะพบว่ารูปแบบการแทนค่าตัวแปร process_date_x และ process_date_y ไม่สอดคล้องกัน จงทำให้รูปแบบการแทนค่าตัวแปร process_date_x และ process_date_y สอดคล้องกัน

# %%
txn_with_cust['process_date_x'] = pd.to_datetime(txn_with_cust['process_date_x'], errors='coerce', format='%d/%m/%Y')
txn_with_cust['process_date_y'] = pd.to_datetime(txn_with_cust['process_date_y'], errors='coerce', format='%Y-%m-%d')
print(txn_with_cust)
# Out:
#    cust_id  age_x wealth_segment_x process_date_x  age_y wealth_segment_y  \
# 0        e   44.0              NaN            NaT   44.0              NaN
# 1        m   30.0           medium            NaT   30.0           medium
# 2        n   29.0             poor            NaT   29.0             poor
# 3        s   64.0             rich            NaT   64.0             rich
# 4        s   64.0             rich            NaT  -12.0             rich
# 5        v    NaN           medium            NaT    NaN           medium
# 6        x   40.0             poor            NaT   40.0             poor
# 7        y   41.0             rich            NaT   41.0             rich
# 8        z   43.0             rich            NaT   43.0             rich
# 9        z   43.0             rich            NaT   54.0             rich
# 10       s  -12.0             rich            NaT   64.0             rich
# 11       s  -12.0             rich            NaT  -12.0             rich
# 12       z   54.0             rich            NaT   43.0             rich
# 13       z   54.0             rich            NaT   54.0             rich
#
#    process_date_y
# 0      2020-01-05
# 1      2020-01-05
# 2      2020-01-05
# 3      2020-01-05
# 4      2020-01-05
# 5      2020-01-05
# 6      2020-01-05
# 7      2020-01-05
# 8      2020-01-05
# 9      2021-01-05
# 10     2020-01-05
# 11     2020-01-05
# 12     2020-01-05
# 13     2021-01-05
